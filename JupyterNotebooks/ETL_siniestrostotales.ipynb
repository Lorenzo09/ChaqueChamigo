# %% [markdown]
# Luego de crear todos los datasets con la información más importante, crearemos uno que junte toda la información en un mismo lugar.

# %%
import pandas as pd
import json
import parquet

# %load_ext autoreload
# %autoreload 2

import utils

import warnings
warnings.filterwarnings("ignore")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# Vamos a cargar todos los archivos primero.

# %%
# Lista con las rutas de los archivos
file_paths = [
    '../Datasets_limpios/siniestros2018.csv',
    '../Datasets_limpios/siniestros2019.csv',
    '../Datasets_limpios/siniestros2020.csv',
    '../Datasets_limpios/siniestros2021.csv',
    '../Datasets_limpios/siniestros2022.csv',
    '../Datasets_limpios/siniestros2023.csv',
    '../Datasets_limpios/siniestros2024.csv',    
]

# Leer todos los archivos CSV y almacenarlos en una lista de dataframes
dataframes = [pd.read_csv(file_path) for file_path in file_paths]

# Concatenar todos los dataframes en uno solo
combined_df = pd.concat(dataframes, ignore_index=True)

# Mostrar las primeras filas del dataset combinado
combined_df.head()
# Out:
#    Unnamed: 0  id_feu siniestro_fecha siniestro_hora zona_ocurrencia  \
# 0           0   49056      2018-10-29       20:10:00          Urbana
# 1           1   49059      2018-10-31       19:30:00          Urbana
# 2           2   48998      2018-10-08       13:10:00          Urbana
# 3           3   49069      2018-11-05       07:15:00          Urbana
# 4           4   48869      2018-08-25       10:30:00          Urbana
#
#   via_publica        nombre_via entre_calle_1     latitud    longitud  ...  \
# 0     Avenida  AV INDEPENDENCIA   LAS PIEDRAS  -2.748.105  -5.880.054  ...
# 1       Calle        BELASCOAIN        VIUDES  -2.748.406  -5.877.596  ...
# 2       Calle          BELGRANO      SAN JUAN  -2.747.203  -5.883.722  ...
# 3     Avenida     AVENIDA FERRE        ESPAÑA  -2.747.631  -5.883.009  ...
# 4       Calle           MENDOZA    25 DE mayo  -2.746.437  -5.883.526  ...
#
#    estado_de_la_calzada  estado_fisico_ambiental  luminosidad  luz_artificial  \
# 0                  Apto                     Seca    Atardecer             NaN
# 1                   NaN          Despejada, Seca        Noche              NO
# 2                  Apto                     Seca          Día              NO
# 3                  Apto                     Seca          Día              NO
# 4                  Apto                     Seca          Día              NO
#
#    estado_ambiental visibilidad      semaforo tipo_colision cono_de_vision  \
# 0         Despejado       Buena      Funciona           NaN            NaN
# 1           Nublado       Buena  Sin Semáforo           NaN            NaN
# 2         Despejado       Buena  Sin Semáforo           NaN            NaN
# 3         Despejado       Buena      Funciona           NaN            NaN
# 4         Despejado       Buena  Sin Semáforo           NaN            NaN
#
#   barreras_de_seguridad
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
#
# [5 rows x 28 columns]

# %% [markdown]
# Verificamos los datos una vez más

# %%
utils.verificar_tipo_datos(combined_df)
combined_df
# Out:
#       Unnamed: 0  id_feu siniestro_fecha siniestro_hora zona_ocurrencia  \
# 0              0   49056      2018-10-29       20:10:00          Urbana
# 1              1   49059      2018-10-31       19:30:00          Urbana
# 2              2   48998      2018-10-08       13:10:00          Urbana
# 3              3   49069      2018-11-05       07:15:00          Urbana
# 4              4   48869      2018-08-25       10:30:00          Urbana
# ...          ...     ...             ...            ...             ...
# 3558         136  228599      2024-01-08       11:20:00          Urbana
# 3559         137  216599      2024-01-07       23:00:00          Urbana
# 3560         138  220443      2024-01-06       06:00:00          Urbana
# 3561         139  229168      2024-01-04       08:30:00          Urbana
# 3562         140  217505      2024-01-01       12:15:00          Urbana
#
#         via_publica        nombre_via            entre_calle_1     latitud  \
# 0           Avenida  AV INDEPENDENCIA              LAS PIEDRAS  -2.748.105
# 1             Calle        BELASCOAIN                   VIUDES  -2.748.406
# 2             Calle          BELGRANO                 SAN JUAN  -2.747.203
# 3           Avenida     AVENIDA FERRE                   ESPAÑA  -2.747.631
# 4             Calle           MENDOZA               25 DE mayo  -2.746.437
# ...             ...               ...                      ...         ...
# 3558        Avenida       AV LIBERTAD             LAS VIOLETAS         NaN
# 3559        Avenida   AV PONCHO VERDE        CARLOS PELLEGRINI         NaN
# 3560        Avenida          AV MAIPU                  TILCARA         NaN
# 3561        Avenida     AV 3 DE ABRIL                  CORDOBA         NaN
# 3562  Ruta Nacional                12  COLECTORA (BOCA UNIDOS)         NaN
#
#         longitud  ...  estado_de_la_calzada  estado_fisico_ambiental  \
# 0     -5.880.054  ...                  Apto                     Seca
# 1     -5.877.596  ...                   NaN          Despejada, Seca
# 2     -5.883.722  ...                  Apto                     Seca
# 3     -5.883.009  ...                  Apto                     Seca
# 4     -5.883.526  ...                  Apto                     Seca
# ...          ...  ...                   ...                      ...
# 3558         NaN  ...                  Apto   Con charcos o inundada
# 3559         NaN  ...                  Apto                     Seca
# 3560         NaN  ...                  Apto                     Seca
# 3561         NaN  ...                  Apto                   Mojada
# 3562         NaN  ...         En reparación                     Seca
#
#       luminosidad  luz_artificial  estado_ambiental visibilidad      semaforo  \
# 0       Atardecer             NaN         Despejado       Buena      Funciona
# 1           Noche              NO           Nublado       Buena  Sin Semáforo
# 2             Día              NO         Despejado       Buena  Sin Semáforo
# 3             Día              NO         Despejado       Buena      Funciona
# 4             Día              NO         Despejado       Buena  Sin Semáforo
# ...           ...             ...               ...         ...           ...
# 3558          Día             NaN            Lluvia         NaN           S/D
# 3559        Noche              NO         Despejado         NaN  Sin Semáforo
# 3560        Noche              NO         Despejado         NaN   No Funciona
# 3561          Día             NaN            Lluvia         NaN      Funciona
# 3562          Día             NaN         Despejado         NaN  Sin Semáforo
#
#      tipo_colision cono_de_vision barreras_de_seguridad
# 0              NaN            NaN                   NaN
# 1              NaN            NaN                   NaN
# 2              NaN            NaN                   NaN
# 3              NaN            NaN                   NaN
# 4              NaN            NaN                   NaN
# ...            ...            ...                   ...
# 3558           NaN            S/D               Ninguna
# 3559           NaN            NaN               Ninguna
# 3560           NaN            S/D               Ninguna
# 3561           NaN            S/D               Ninguna
# 3562           NaN            S/D               Asfalto
#
# [3563 rows x 28 columns]

# %% [markdown]
# Eliminamos lo más nulo y la columna Unnamed

# %%
# Eliminar columnas con más del 80% de valores nulos
umbral = 0.8  # Umbral del 80%
combined_df = combined_df.dropna(thresh=len(combined_df) * (1 - umbral), axis=1)

combined_df = combined_df.drop(columns=['Unnamed: 0'])

# Mostrar las columnas que se mantuvieron
combined_df.columns
# Out:
# Index(['id_feu', 'siniestro_fecha', 'siniestro_hora', 'zona_ocurrencia',
#        'via_publica', 'nombre_via', 'entre_calle_1', 'latitud', 'longitud',
#        'ilesos', 'heridos', 'fallecidos', 'vehiculos', 'peatones',
#        'tipo_siniestro_unico', 'cantidad_de_involucrados',
#        'material_de_la_calzada', 'estado_de_la_calzada',
#        'estado_fisico_ambiental', 'luminosidad', 'luz_artificial',
#        'estado_ambiental', 'visibilidad', 'semaforo'],
#       dtype='object')

# %% [markdown]
# Todavía quedan errores por solucionar en nuestro dataset. Primero, solucionaremos las columnas de fecha y hora para poder darles un mejor manejo.

# %%
# Primero, aseguramos que la columna está en formato de fecha
combined_df['siniestro_fecha'] = pd.to_datetime(combined_df['siniestro_fecha'])

# Creamos las nuevas columnas
combined_df['anio'] = combined_df['siniestro_fecha'].dt.year
combined_df['mes'] = combined_df['siniestro_fecha'].dt.strftime('%B')
combined_df['dia'] = combined_df['siniestro_fecha'].dt.day

# Si la columna 'siniestro_hora' es un string, convertimos a formato datetime
combined_df['siniestro_hora'] = pd.to_datetime(combined_df['siniestro_hora'], format='%H:%M:%S').dt.time

# Visualizar el resultado
print(combined_df.head())
# Out:
#    id_feu siniestro_fecha siniestro_hora zona_ocurrencia via_publica  \
# 0   49056      2018-10-29       20:10:00          Urbana     Avenida
# 1   49059      2018-10-31       19:30:00          Urbana       Calle
# 2   48998      2018-10-08       13:10:00          Urbana       Calle
# 3   49069      2018-11-05       07:15:00          Urbana     Avenida
# 4   48869      2018-08-25       10:30:00          Urbana       Calle
#
#          nombre_via entre_calle_1     latitud    longitud  ilesos  ...  \
# 0  AV INDEPENDENCIA   LAS PIEDRAS  -2.748.105  -5.880.054     1.0  ...
# 1        BELASCOAIN        VIUDES  -2.748.406  -5.877.596     1.0  ...
# 2          BELGRANO      SAN JUAN  -2.747.203  -5.883.722     1.0  ...
# 3     AVENIDA FERRE        ESPAÑA  -2.747.631  -5.883.009     2.0  ...
# 4           MENDOZA    25 DE mayo  -2.746.437  -5.883.526     1.0  ...
#
#    estado_de_la_calzada  estado_fisico_ambiental  luminosidad  luz_artificial  \
# 0                  Apto                     Seca    Atardecer             NaN
# 1                   NaN          Despejada, Seca        Noche              NO
# 2                  Apto                     Seca          Día              NO
# 3                  Apto                     Seca          Día              NO
# 4                  Apto                     Seca          Día              NO
#
#   estado_ambiental  visibilidad      semaforo  anio       mes dia
# 0        Despejado        Buena      Funciona  2018   October  29
# 1          Nublado        Buena  Sin Semáforo  2018   October  31
# 2        Despejado        Buena  Sin Semáforo  2018   October   8
# 3        Despejado        Buena      Funciona  2018  November   5
# 4        Despejado        Buena  Sin Semáforo  2018    August  25
#
# [5 rows x 27 columns]

# %% [markdown]
# Por último, solucionamos con código los valores faltantes en latitud y longitud para poder graficar.

# %%
from sklearn.impute import KNNImputer

# Paso 1: Corregir el formato de las coordenadas
# Eliminar puntos innecesarios y convertir a float
combined_df['latitud'] = combined_df['latitud'].str.replace('.', '', regex=False).astype(float)
combined_df['longitud'] = combined_df['longitud'].str.replace('.', '', regex=False).astype(float)

# Dividir por 100000 para obtener las coordenadas en el formato correcto
combined_df['latitud'] = combined_df['latitud'] / 100000
combined_df['longitud'] = combined_df['longitud'] / 100000

# Paso 2: Aplicar KNNImputer para imputar valores nulos
coords_df = combined_df[['latitud', 'longitud']]

# Usar KNN para imputar valores nulos
imputer = KNNImputer(n_neighbors=3)
coords_imputed = imputer.fit_transform(coords_df)

# Actualizar el dataframe con los valores imputados
combined_df[['latitud', 'longitud']] = coords_imputed

# Verificar los primeros resultados
print(combined_df[['latitud', 'longitud']].head())
# Out:
#     latitud  longitud
# 0 -27.48105 -58.80054
# 1 -27.48406 -58.77596
# 2 -27.47203 -58.83722
# 3 -27.47631 -58.83009
# 4 -27.46437 -58.83526

# %%
# Guardar el dataset combinado en un nuevo archivo Parquet, para que mantenga sus types.

combined_df.to_parquet('../Datasets_limpios/siniestrostotales.parquet', index=False)
